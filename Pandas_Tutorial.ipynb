# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Pandas is one of the most important libraries of Python.
#
# Pandas has data structures for easy data analysis. The most used of these are Series and DataFrame data structures. Series data structure is one dimensional, that is, it consists of a column. DataFrame data structure is two-dimensional, i.e. it consists of rows and columns.

# %% [markdown]
# # Create DataFrame from dicts

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "sex":["M","M","M","M","F","F","F"]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %%
df=pd.DataFrame(data,columns=["name","sport","sex","score"])
df
# Out:
#       name      sport sex  score
# 0     Bill  Wrestling   M     90
# 1      Tom   Football   M     80
# 2      Tim     Skiing   M     85
# 3     John   Swimming   M     75
# 4     Alex     Tennis   F     95
# 5  Vanessa     Karete   F     60
# 6     Kate    Surfing   F     65

# %%
df.head(3)
# Out:
#    name      sport sex  score
# 0  Bill  Wrestling   M     90
# 1   Tom   Football   M     80
# 2   Tim     Skiing   M     85

# %%
df.tail(3)
# Out:
#       name    sport sex  score
# 4     Alex   Tennis   F     95
# 5  Vanessa   Karete   F     60
# 6     Kate  Surfing   F     65

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling    NaN     90  NaN
# two        Tom   Football    NaN     80  NaN
# three      Tim     Skiing    NaN     85  NaN
# four      John   Swimming    NaN     75  NaN
# five      Alex     Tennis    NaN     95  NaN
# six    Vanessa     Karete    NaN     60  NaN
# seven     Kate    Surfing    NaN     65  NaN

# %%
df.sport
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %%
df[["sport","score"]]
# Out:
#            sport  score
# one    Wrestling     90
# two     Football     80
# three     Skiing     85
# four    Swimming     75
# five      Tennis     95
# six       Karete     60
# seven    Surfing     65

# %%
df["sport"].to_numpy()
# Out:
# array(['Wrestling', 'Football', 'Skiing', 'Swimming', 'Tennis', 'Karete',
#        'Surfing'], dtype=object)

# %%
df["score"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Create Dataframe directly

# %%
data=pd.DataFrame(
    np.arange(16).reshape(4,4),
    index=["London","Paris",
           "Berlin","Istanbul"],
    columns=["one","two","three","four"])
data
# Out:
#           one  two  three  four
# London      0    1      2     3
# Paris       4    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data[["one","two"]]
# Out:
#           one  two
# London      0    1
# Paris       4    5
# Berlin      8    9
# Istanbul   12   13

# %%
data[:5]
# Out:
#           one  two  three  four
# London      0    1      2     3
# Paris       4    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data[data["four"]>5]
# Out:
#           one  two  three  four
# Paris       4    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data[data<5]=0
data
# Out:
#           one  two  three  four
# London      0    0      0     0
# Paris       0    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %% [markdown]
# #  Useful Functions

# %%
data=pd.read_csv("DataSets/ca_san_diego_2019_02_25.csv")
data
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# 0                        white        male  vehicular       False
# 1                        white        male  vehicular       False
# 2       asian/pacific islander        male  vehicular       False
# 3                        white        male  vehicular       False
# 4                     hispanic        male  vehicular       False
# ...                        ...         ...        ...         ...
# 390994                   black        male  vehicular       False
# 390995                hispanic        male  vehicular         NaN
# 390996                hispanic        male  vehicular       False
# 390997                hispanic        male  vehicular         NaN
# 390998                   white      female  vehicular         NaN
#
#        citation_issued warning_issued   outcome contraband_found  \
# 0                 True          False  citation              NaN
# 1                False           True   warning              NaN
# 2                False           True   warning              NaN
# 3                 True          False  citation              NaN
# 4                 True          False  citation              NaN
# ...                ...            ...       ...              ...
# 390994           False           True   warning              NaN
# 390995            True          False  citation              NaN
# 390996           False          False       NaN              NaN
# 390997            True          False  citation              NaN
# 390998           False           True   warning              NaN
#
#        search_conducted search_person search_vehicle search_basis  \
# 0                 False           NaN            NaN          NaN
# 1                 False           NaN            NaN          NaN
# 2                 False           NaN            NaN          NaN
# 3                 False           NaN            NaN          NaN
# 4                 False           NaN            NaN          NaN
# ...                 ...           ...            ...          ...
# 390994            False           NaN            NaN          NaN
# 390995              NaN           NaN            NaN          NaN
# 390996            False           NaN            NaN          NaN
# 390997              NaN           NaN            NaN          NaN
# 390998              NaN           NaN            NaN          NaN
#
#        reason_for_search             reason_for_stop
# 0                    NaN            Moving Violation
# 1                    NaN            Moving Violation
# 2                    NaN            Moving Violation
# 3                    NaN            Moving Violation
# 4                    NaN         Equipment Violation
# ...                  ...                         ...
# 390994               NaN            Moving Violation
# 390995               NaN            Moving Violation
# 390996               NaN  Radio Call/Citizen Contact
# 390997               NaN            Moving Violation
# 390998               NaN         Equipment Violation
#
# [390999 rows x 19 columns]

# %%
data=data.dropna()
data
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 81                  82  2014-01-02  13:30:00      Unknown         25.0
# 130                131  2014-01-03  06:50:00          310         28.0
# 176                177  2014-01-03  18:50:00          810         27.0
# 226                227  2014-01-04  07:35:00          310         36.0
# 301                302  2014-01-05  02:30:00          240         23.0
# ...                ...         ...       ...          ...          ...
# 390958          390959  2017-03-31  22:00:00          930         37.0
# 390968          390969  2017-03-31  22:20:00          120         54.0
# 390972          390973  2017-03-31  22:29:00          440         47.0
# 390973          390974  2017-03-31  22:30:00          120         21.0
# 390978          390979  2017-03-31  22:45:00          120         25.0
#
#                   subject_race subject_sex       type arrest_made  \
# 81                    hispanic        male  vehicular       False
# 130                   hispanic        male  vehicular       False
# 176                   hispanic      female  vehicular       False
# 226                      white        male  vehicular       False
# 301     asian/pacific islander        male  vehicular       False
# ...                        ...         ...        ...         ...
# 390958                   white        male  vehicular       False
# 390968                   white        male  vehicular       False
# 390972                   black        male  vehicular       False
# 390973                   white        male  vehicular       False
# 390978                   white        male  vehicular       False
#
#        citation_issued warning_issued   outcome contraband_found  \
# 81               False           True   warning             True
# 130               True          False  citation            False
# 176               True          False  citation            False
# 226               True          False  citation             True
# 301              False           True   warning            False
# ...                ...            ...       ...              ...
# 390958            True          False  citation            False
# 390968            True          False  citation            False
# 390972           False           True   warning            False
# 390973            True          False  citation            False
# 390978            True          False  citation            False
#
#        search_conducted search_person search_vehicle    search_basis  \
# 81                 True         False           True  probable cause
# 130                True         False           True           other
# 176                True          True          False           other
# 226                True         False           True         consent
# 301                True          True          False         consent
# ...                 ...           ...            ...             ...
# 390958             True         False           True           other
# 390968             True          True          False         consent
# 390972             True          True           True           other
# 390973             True          True          False         consent
# 390978             True          True          False         consent
#
#                           reason_for_search      reason_for_stop
# 81                       Odor of Contraband     Moving Violation
# 130                        Inventory Search     Moving Violation
# 176     Inventory Search [Prior to Impound]  Equipment Violation
# 226                          Consent Search  Equipment Violation
# 301                          Consent Search  Equipment Violation
# ...                                     ...                  ...
# 390958  Inventory Search [Prior to Impound]  Equipment Violation
# 390968                       Consent Search     Moving Violation
# 390972                    4th Waiver Search     Moving Violation
# 390973                       Consent Search     Moving Violation
# 390978                       Consent Search     Moving Violation
#
# [8886 rows x 19 columns]

# %%
string=data["subject_race"].unique()
string
# Out:
# array(['hispanic', 'white', 'asian/pacific islander', 'black',
#        'other/unknown'], dtype=object)

# %%
new_data={t:i for i,t in enumerate(string) }
print(new_data)
new_coloum=[]
for i in data["subject_race"].values:
    new_coloum.append(new_data[i])
data["numerical_subject_race"]=new_coloum
# Out:
# {'hispanic': 0, 'white': 1, 'asian/pacific islander': 2, 'black': 3, 'other/unknown': 4}
# <ipython-input-13-0a4d8d3ee646>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["numerical_subject_race"]=new_coloum

# %%
data
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 81                  82  2014-01-02  13:30:00      Unknown         25.0
# 130                131  2014-01-03  06:50:00          310         28.0
# 176                177  2014-01-03  18:50:00          810         27.0
# 226                227  2014-01-04  07:35:00          310         36.0
# 301                302  2014-01-05  02:30:00          240         23.0
# ...                ...         ...       ...          ...          ...
# 390958          390959  2017-03-31  22:00:00          930         37.0
# 390968          390969  2017-03-31  22:20:00          120         54.0
# 390972          390973  2017-03-31  22:29:00          440         47.0
# 390973          390974  2017-03-31  22:30:00          120         21.0
# 390978          390979  2017-03-31  22:45:00          120         25.0
#
#                   subject_race subject_sex       type arrest_made  \
# 81                    hispanic        male  vehicular       False
# 130                   hispanic        male  vehicular       False
# 176                   hispanic      female  vehicular       False
# 226                      white        male  vehicular       False
# 301     asian/pacific islander        male  vehicular       False
# ...                        ...         ...        ...         ...
# 390958                   white        male  vehicular       False
# 390968                   white        male  vehicular       False
# 390972                   black        male  vehicular       False
# 390973                   white        male  vehicular       False
# 390978                   white        male  vehicular       False
#
#        citation_issued warning_issued   outcome contraband_found  \
# 81               False           True   warning             True
# 130               True          False  citation            False
# 176               True          False  citation            False
# 226               True          False  citation             True
# 301              False           True   warning            False
# ...                ...            ...       ...              ...
# 390958            True          False  citation            False
# 390968            True          False  citation            False
# 390972           False           True   warning            False
# 390973            True          False  citation            False
# 390978            True          False  citation            False
#
#        search_conducted search_person search_vehicle    search_basis  \
# 81                 True         False           True  probable cause
# 130                True         False           True           other
# 176                True          True          False           other
# 226                True         False           True         consent
# 301                True          True          False         consent
# ...                 ...           ...            ...             ...
# 390958             True         False           True           other
# 390968             True          True          False         consent
# 390972             True          True           True           other
# 390973             True          True          False         consent
# 390978             True          True          False         consent
#
#                           reason_for_search      reason_for_stop  \
# 81                       Odor of Contraband     Moving Violation
# 130                        Inventory Search     Moving Violation
# 176     Inventory Search [Prior to Impound]  Equipment Violation
# 226                          Consent Search  Equipment Violation
# 301                          Consent Search  Equipment Violation
# ...                                     ...                  ...
# 390958  Inventory Search [Prior to Impound]  Equipment Violation
# 390968                       Consent Search     Moving Violation
# 390972                    4th Waiver Search     Moving Violation
# 390973                       Consent Search     Moving Violation
# 390978                       Consent Search     Moving Violation
#
#         numerical_subject_race
# 81                           0
# 130                          0
# 176                          0
# 226                          1
# 301                          2
# ...                        ...
# 390958                       1
# 390968                       1
# 390972                       3
# 390973                       1
# 390978                       1
#
# [8886 rows x 20 columns]

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 81                  82  2014-01-02  13:30:00      Unknown         25.0
# 130                131  2014-01-03  06:50:00          310         28.0
# 176                177  2014-01-03  18:50:00          810         27.0
# 226                227  2014-01-04  07:35:00          310         36.0
# 301                302  2014-01-05  02:30:00          240         23.0
# ...                ...         ...       ...          ...          ...
# 390958          390959  2017-03-31  22:00:00          930         37.0
# 390968          390969  2017-03-31  22:20:00          120         54.0
# 390972          390973  2017-03-31  22:29:00          440         47.0
# 390973          390974  2017-03-31  22:30:00          120         21.0
# 390978          390979  2017-03-31  22:45:00          120         25.0
#
#                   subject_race subject_sex       type arrest_made  \
# 81                    hispanic        male  vehicular       False
# 130                   hispanic        male  vehicular       False
# 176                   hispanic      female  vehicular       False
# 226                      white        male  vehicular       False
# 301     asian/pacific islander        male  vehicular       False
# ...                        ...         ...        ...         ...
# 390958                   white        male  vehicular       False
# 390968                   white        male  vehicular       False
# 390972                   black        male  vehicular       False
# 390973                   white        male  vehicular       False
# 390978                   white        male  vehicular       False
#
#        citation_issued warning_issued   outcome contraband_found  \
# 81               False           True   warning             True
# 130               True          False  citation            False
# 176               True          False  citation            False
# 226               True          False  citation             True
# 301              False           True   warning            False
# ...                ...            ...       ...              ...
# 390958            True          False  citation            False
# 390968            True          False  citation            False
# 390972           False           True   warning            False
# 390973            True          False  citation            False
# 390978            True          False  citation            False
#
#        search_conducted search_person search_vehicle    search_basis  \
# 81                 True         False           True  probable cause
# 130                True         False           True           other
# 176                True          True          False           other
# 226                True         False           True         consent
# 301                True          True          False         consent
# ...                 ...           ...            ...             ...
# 390958             True         False           True           other
# 390968             True          True          False         consent
# 390972             True          True           True           other
# 390973             True          True          False         consent
# 390978             True          True          False         consent
#
#                           reason_for_search      reason_for_stop  \
# 81                       Odor of Contraband     Moving Violation
# 130                        Inventory Search     Moving Violation
# 176     Inventory Search [Prior to Impound]  Equipment Violation
# 226                          Consent Search  Equipment Violation
# 301                          Consent Search  Equipment Violation
# ...                                     ...                  ...
# 390958  Inventory Search [Prior to Impound]  Equipment Violation
# 390968                       Consent Search     Moving Violation
# 390972                    4th Waiver Search     Moving Violation
# 390973                       Consent Search     Moving Violation
# 390978                       Consent Search     Moving Violation
#
#         numerical_subject_race
# 81                           0
# 130                          0
# 176                          0
# 226                          1
# 301                          2
# ...                        ...
# 390958                       1
# 390968                       1
# 390972                       3
# 390973                       1
# 390978                       1
#
# [8886 rows x 20 columns]

# %%
data.corr()
# Out:
#                         raw_row_number  subject_age  numerical_subject_race
# raw_row_number                1.000000     0.036578                0.013927
# subject_age                   0.036578     1.000000                0.086323
# numerical_subject_race        0.013927     0.086323                1.000000
